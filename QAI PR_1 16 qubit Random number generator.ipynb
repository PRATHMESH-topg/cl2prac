# %% [markdown]
# 16 Bit qubit Random Number Genrator

# %%
# !pip install -U qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 23.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 30.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 1.6 MB/s eta 0:00:00
# ...

# %%
# !pip install qiskit-aer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 57.4 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer

# Create a 16-qubit circuit
qc = QuantumCircuit(16, 16)

# Apply Hadamard gates to all qubits
for i in range(16):
    qc.h(i)

# Measure all qubits
qc.measure(range(16), range(16))

# Use the simulator
simulator = Aer.get_backend('qasm_simulator')
job = simulator.run(qc, shots=1)
result = job.result()

# Get result
counts = result.get_counts()
random_number = list(counts.keys())[0]
print("Quantum Random Number (16 bits):", random_number)
# Out:
# Quantum Random Number (16 bits): 0110111001011011

# %%
# !pip install -U qiskit

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer

# Create a 16-qubit circuit
qc = QuantumCircuit(16, 16)

# Apply Hadamard gates to all qubits
for i in range(16):
    qc.h(i)

# Measure all qubits
qc.measure(range(16), range(16))

# Use the simulator
simulator = Aer.get_backend('qasm_simulator')
job = simulator.run(qc, shots=1)
result = job.result()

# Get result
counts = result.get_counts()
random_number = list(counts.keys())[0]
print("Quantum Random Number (16 bits):", random_number)
